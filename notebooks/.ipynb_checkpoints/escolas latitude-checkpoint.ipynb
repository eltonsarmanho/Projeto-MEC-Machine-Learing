# %%
import pandas as pd
import os

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

from urllib.request import urlopen

#import json
#import psycopg2

# %%
#File = os.path.join('D:',os.sep,'IG Data', 'escolasLatitude.csv')
File = os.path.join('C:',os.sep,'Users', 'emanuelqueiroga', 'scripts', 'data' , 'escolasLatitude.csv')
df = pd.read_csv(File, sep=';')

# %%
df
# Out:
#                                  Restrição de Atendimento  \
# 0       ESCOLA ATENDE EXCLUSIVAMENTE ALUNOS COM DEFICI...
# 1       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 2       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 3       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# ...                                                   ...
# 216554                                  ESCOLA PARALISADA
# 216555  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216556  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216557                                  ESCOLA PARALISADA
# 216558                                  ESCOLA PARALISADA
#
#                                                  Escola  Código INEP  UF  \
# 0                    EEEE ABNAEL MACHADO DE LIMA - CENE     11000023  RO
# 1                              EMEIEF PEQUENOS TALENTOS     11000040  RO
# 2                             CENTRO DE ENSINO CLASSE A     11000058  RO
# 3       CENTRO EDUCACIONAL PRESBITERIANO 15 DE NOVEMBRO     11000082  RO
# 4                             CENTRO EDUC CORA CORALINA     11000104  RO
# ...                                                 ...          ...  ..
# 216554                                ESC DIVINO MESTRE     53084071  DF
# 216555                            COBIAN - COL BIANGULO     53085000  DF
# 216556                                CED VITORIA REGIA     53086007  DF
# 216557                        CED SANTOS DUMONT - CESAN     53087003  DF
# 216558              OBRA SOCIAL NOSSA SENHORA DE FATIMA     53088034  DF
#
#           Município Localização  \
# 0       Porto Velho      Urbana
# 1       Porto Velho      Urbana
# 2       Porto Velho      Urbana
# 3       Porto Velho      Urbana
# 4       Porto Velho      Urbana
# ...             ...         ...
# 216554     Brasília      Urbana
# 216555     Brasília      Urbana
# 216556     Brasília      Urbana
# 216557     Brasília      Urbana
# 216558     Brasília      Urbana
#
#                                   Localidade Diferenciada  \
# 0       A escola não está em área de localização difer...
# 1       A escola não está em área de localização difer...
# 2       A escola não está em área de localização difer...
# 3       A escola não está em área de localização difer...
# 4       A escola não está em área de localização difer...
# ...                                                   ...
# 216554                                      Não Informado
# 216555  A escola não está em área de localização difer...
# 216556  A escola não está em área de localização difer...
# 216557                                      Não Informado
# 216558                                      Não Informado
#
#        Categoria Administrativa  \
# 0                       Pública
# 1                       Pública
# 2                       Privada
# 3                       Privada
# 4                       Privada
# ...                         ...
# 216554                  Privada
# 216555                  Privada
# 216556                  Privada
# 216557                  Privada
# 216558                  Privada
#
#                                                  Endereço        Telefone  \
# 0       AVENIDA AMAZONAS, 6492 ZONA LESTE. TIRADENTES....  (69) 992083054
# 1       RUA CAETANO, 3256 PREDIO. CALADINHO. 76808-108...   (69) 32274273
# 2       AVENIDA CARLOS GOMES, 1135 CENTRO. 76801-123 P...   (69) 32244473
# 3       RUA ALMIRANTE BARROSO, 1483 SANTA BARBARA. 768...   (69) 32245636
# 4       RUA MEXICO, 1056 NOVA PORTO VELHO. 76820-190 P...   (69) 32252616
# ...                                                   ...             ...
# 216554  QUADRA QNP 21 CONJUNTO H, CEILANDIA NORTE CEIL...   (61) 35856361
# 216555  QNJ 22 - LOTES 34 E 36, TAGUATINGA NORTE. 7214...   (61) 34756945
# 216556  RUA 07 CH 333 LOTE 333/E, SETOR HABITACIONAL V...   (61) 35976668
# 216557  QUADRA 203 CONJUNTO 6, 06/15 LOTES 06 E 15. SE...   (61) 33391545
# 216558  QUADRA SETOR D SUL, TAGUATINGA SUL TAGUATINGA....   (61) 33972571
#
#        Dependência Administrativa Categoria Escola Privada  \
# 0                        Estadual            Não Informado
# 1                       Municipal            Não Informado
# 2                         Privada               Particular
# 3                         Privada               Particular
# 4                         Privada               Particular
# ...                           ...                      ...
# 216554                    Privada            Não Informado
# 216555                    Privada               Particular
# 216556                    Privada               Particular
# 216557                    Privada            Não Informado
# 216558                    Privada            Não Informado
#
#        Conveniada Poder Público Regulamentação pelo Conselho de Educação  \
# 0                           Não                                      Não
# 1                           Não                                      Sim
# 2                           Não                                      Sim
# 3                           Não                                      Sim
# 4                           Não                                      Sim
# ...                         ...                                      ...
# 216554                      Não                                      NaN
# 216555                      Não                                      Sim
# 216556                      Não                                      Sim
# 216557                      Não                                      NaN
# 216558                      Não                                      NaN
#
#                                      Porte da Escola  \
# 0         Entre 51 e 200 matrículas de escolarização
# 1        Entre 201 e 500 matrículas de escolarização
# 2           Mais de 1000 matrículas de escolarização
# 3         Entre 51 e 200 matrículas de escolarização
# 4       Entre 501 e 1000 matrículas de escolarização
# ...                                              ...
# 216554                                           NaN
# 216555   Entre 201 e 500 matrículas de escolarização
# 216556    Entre 51 e 200 matrículas de escolarização
# 216557                                           NaN
# 216558                                           NaN
#
#                  Etapas e Modalidade de Ensino Oferecidas  \
# 0                                      Ensino Fundamental
# 1                                       Educação Infantil
# 2       Educação Infantil, Ensino Fundamental, Ensino ...
# 3                   Educação Infantil, Ensino Fundamental
# 4                   Educação Infantil, Ensino Fundamental
# ...                                                   ...
# 216554                                                NaN
# 216555              Educação Infantil, Ensino Fundamental
# 216556                   Ensino Fundamental, Ensino Médio
# 216557                                                NaN
# 216558                                                NaN
#
#                   Outras Ofertas Educacionais   Latitude  Longitude
# 0       Atendimento Educacional Especializado  -8.758459 -63.854011
# 1                                         NaN  -8.793730 -63.883919
# 2                                         NaN  -8.760734 -63.901986
# 3                                         NaN  -8.765205 -63.896177
# 4                                         NaN  -8.768633 -63.875471
# ...                                       ...        ...        ...
# 216554                                    NaN        NaN        NaN
# 216555                                    NaN -15.815942 -48.085108
# 216556                                    NaN        NaN        NaN
# 216557                                    NaN        NaN        NaN
# 216558                                    NaN        NaN        NaN
#
# [216559 rows x 19 columns]

# %%
df = df[df['Latitude'].notna()]
df = df[df['Longitude'].notna()]
df = df[df['Escola'].notna()]
len(df)
# Out:
# 158742

# %%
df
# Out:
#                                  Restrição de Atendimento  \
# 0       ESCOLA ATENDE EXCLUSIVAMENTE ALUNOS COM DEFICI...
# 1       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 2       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 3       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# ...                                                   ...
# 216549  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216550  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216551  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216552  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 216555  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
#
#                                                  Escola  Código INEP  UF  \
# 0                    EEEE ABNAEL MACHADO DE LIMA - CENE     11000023  RO
# 1                              EMEIEF PEQUENOS TALENTOS     11000040  RO
# 2                             CENTRO DE ENSINO CLASSE A     11000058  RO
# 3       CENTRO EDUCACIONAL PRESBITERIANO 15 DE NOVEMBRO     11000082  RO
# 4                             CENTRO EDUC CORA CORALINA     11000104  RO
# ...                                                 ...          ...  ..
# 216549                                      COL MAANAIM     53083016  DF
# 216550                              ESC PEQUENO ENCANTO     53084020  DF
# 216551                                     COL ANCHIETA     53084039  DF
# 216552                                         COL MAPA     53084055  DF
# 216555                            COBIAN - COL BIANGULO     53085000  DF
#
#           Município Localização  \
# 0       Porto Velho      Urbana
# 1       Porto Velho      Urbana
# 2       Porto Velho      Urbana
# 3       Porto Velho      Urbana
# 4       Porto Velho      Urbana
# ...             ...         ...
# 216549     Brasília      Urbana
# 216550     Brasília      Urbana
# 216551     Brasília      Urbana
# 216552     Brasília      Urbana
# 216555     Brasília      Urbana
#
#                                   Localidade Diferenciada  \
# 0       A escola não está em área de localização difer...
# 1       A escola não está em área de localização difer...
# 2       A escola não está em área de localização difer...
# 3       A escola não está em área de localização difer...
# 4       A escola não está em área de localização difer...
# ...                                                   ...
# 216549  A escola não está em área de localização difer...
# 216550  A escola não está em área de localização difer...
# 216551  A escola não está em área de localização difer...
# 216552  A escola não está em área de localização difer...
# 216555  A escola não está em área de localização difer...
#
#        Categoria Administrativa  \
# 0                       Pública
# 1                       Pública
# 2                       Privada
# 3                       Privada
# 4                       Privada
# ...                         ...
# 216549                  Privada
# 216550                  Privada
# 216551                  Privada
# 216552                  Privada
# 216555                  Privada
#
#                                                  Endereço        Telefone  \
# 0       AVENIDA AMAZONAS, 6492 ZONA LESTE. TIRADENTES....  (69) 992083054
# 1       RUA CAETANO, 3256 PREDIO. CALADINHO. 76808-108...   (69) 32274273
# 2       AVENIDA CARLOS GOMES, 1135 CENTRO. 76801-123 P...   (69) 32244473
# 3       RUA ALMIRANTE BARROSO, 1483 SANTA BARBARA. 768...   (69) 32245636
# 4       RUA MEXICO, 1056 NOVA PORTO VELHO. 76820-190 P...   (69) 32252616
# ...                                                   ...             ...
# 216549  QUADRA AC 3, 13 COLEGIO MAANAIM. RIACHO FUNDO ...   (61) 33996445
# 216550  QUADRA QNO 18 CONJUNTO 7 LOTE, 05 CEILANDIA NO...   (61) 33777738
# 216551  QSC 19 QUADRA 27 - CONJUNTO A LOTE 16, SETOR P...   (61) 33510110
# 216552  QUADRA EQNP 15/19 MODULO F, CEILANDIA NORTE CE...   (61) 33791116
# 216555  QNJ 22 - LOTES 34 E 36, TAGUATINGA NORTE. 7214...   (61) 34756945
#
#        Dependência Administrativa Categoria Escola Privada  \
# 0                        Estadual            Não Informado
# 1                       Municipal            Não Informado
# 2                         Privada               Particular
# 3                         Privada               Particular
# 4                         Privada               Particular
# ...                           ...                      ...
# 216549                    Privada               Particular
# 216550                    Privada               Particular
# 216551                    Privada               Particular
# 216552                    Privada               Particular
# 216555                    Privada               Particular
#
#        Conveniada Poder Público Regulamentação pelo Conselho de Educação  \
# 0                           Não                                      Não
# 1                           Não                                      Sim
# 2                           Não                                      Sim
# 3                           Não                                      Sim
# 4                           Não                                      Sim
# ...                         ...                                      ...
# 216549                      Não                                      Sim
# 216550                      Não                                      Sim
# 216551                      Não                                      Sim
# 216552                      Não                                      Sim
# 216555                      Não                                      Sim
#
#                                      Porte da Escola  \
# 0         Entre 51 e 200 matrículas de escolarização
# 1        Entre 201 e 500 matrículas de escolarização
# 2           Mais de 1000 matrículas de escolarização
# 3         Entre 51 e 200 matrículas de escolarização
# 4       Entre 501 e 1000 matrículas de escolarização
# ...                                              ...
# 216549    Entre 51 e 200 matrículas de escolarização
# 216550    Entre 51 e 200 matrículas de escolarização
# 216551   Entre 201 e 500 matrículas de escolarização
# 216552   Entre 201 e 500 matrículas de escolarização
# 216555   Entre 201 e 500 matrículas de escolarização
#
#                  Etapas e Modalidade de Ensino Oferecidas  \
# 0                                      Ensino Fundamental
# 1                                       Educação Infantil
# 2       Educação Infantil, Ensino Fundamental, Ensino ...
# 3                   Educação Infantil, Ensino Fundamental
# 4                   Educação Infantil, Ensino Fundamental
# ...                                                   ...
# 216549              Educação Infantil, Ensino Fundamental
# 216550              Educação Infantil, Ensino Fundamental
# 216551              Educação Infantil, Ensino Fundamental
# 216552                   Ensino Fundamental, Ensino Médio
# 216555              Educação Infantil, Ensino Fundamental
#
#                   Outras Ofertas Educacionais   Latitude  Longitude
# 0       Atendimento Educacional Especializado  -8.758459 -63.854011
# 1                                         NaN  -8.793730 -63.883919
# 2                                         NaN  -8.760734 -63.901986
# 3                                         NaN  -8.765205 -63.896177
# 4                                         NaN  -8.768633 -63.875471
# ...                                       ...        ...        ...
# 216549                                    NaN -15.883345 -48.016219
# 216550                                    NaN -15.796716 -48.137340
# 216551                                    NaN -15.851295 -48.065637
# 216552                                    NaN -15.809097 -48.135305
# 216555                                    NaN -15.815942 -48.085108
#
# [158742 rows x 19 columns]

# %%
list(df)
# Out:
# ['Restrição de Atendimento',
#  'Escola',
#  'Código INEP',
#  'UF',
#  'Município',
#  'Localização',
#  'Localidade Diferenciada',
#  'Categoria Administrativa',
#  'Endereço',
#  'Telefone',
#  'Dependência Administrativa',
#  'Categoria Escola Privada',
#  'Conveniada Poder Público',
#  'Regulamentação pelo Conselho de Educação',
#  'Porte da Escola',
#  'Etapas e Modalidade de Ensino Oferecidas',
#  'Outras Ofertas Educacionais',
#  'Latitude',
#  'Longitude']

# %%
df2 = df.loc[df['UF'] == 'RS']
df2 = df.loc[df['Município'] == 'Pelotas']
len(df2)
# Out:
# 196

# %%
df2.to_csv('pelotas2.csv', sep='|')

# %%
#EMEF MARCIO DIAS

#df3 = df2.loc[df['Escola'] != 'EMEF MARCIO DIAS']
#len(df3)

# %%
new = df2.filter(['Escola','Latitude','Longitude', 'Porte da Escola',], axis=1)
new
# Out:
#                                  Escola   Latitude  Longitude  \
# 193767       COLEGIO TIRADENTES PELOTAS -31.756633 -52.373175
# 193828              EEI MUNDO DO MICKEY -31.771390 -52.329940
# 193902         EEI CHAPEUZINHO VERMELHO -31.762210 -52.343580
# 193985                  EEF TRES VENDAS -31.731438 -52.346365
# 193987                   EEI REINO AZUL -31.758710 -52.363290
# ...                                 ...        ...        ...
# 204971                    EEI TAGARELAS -31.761200 -52.239370
# 204973  CENTRO INF BRICANDO DE APRENDER -31.743850 -52.342600
# 204978                     EEI DOCE MEL -31.761920 -52.343230
# 204980               EEI MUNDO CRIATIVO -31.756190 -52.331390
# 205061           EEI TURMINHA DA EMILIA -31.743930 -52.320980
#
#                                      Porte da Escola
# 193767    Entre 51 e 200 matrículas de escolarização
# 193828            Até 50 matrículas de escolarização
# 193902            Até 50 matrículas de escolarização
# 193985  Entre 501 e 1000 matrículas de escolarização
# 193987            Até 50 matrículas de escolarização
# ...                                              ...
# 204971            Até 50 matrículas de escolarização
# 204973                                           NaN
# 204978                                           NaN
# 204980            Até 50 matrículas de escolarização
# 205061                                           NaN
#
# [196 rows x 4 columns]

# %%
def map_escolas():
    fig = px.scatter_mapbox(df, 
                            title="Escolas BR",
                            zoom=3, center={"lat": -11.44, "lon": -52.01},
                            lat="Latitude", lon="Longitude",
                            #color='Porte da Escola',
                            hover_name="Escola", 
                            hover_data=['Restrição de Atendimento',
                             'Escola',
                             'Código INEP',
                             'UF',
                             'Município',
                             'Localização',
                             'Localidade Diferenciada',
                             'Categoria Administrativa',
                             'Endereço',
                             'Telefone',
                             'Dependência Administrativa',
                             'Categoria Escola Privada',
                             'Conveniada Poder Público',
                             'Regulamentação pelo Conselho de Educação',
                             'Porte da Escola',
                             'Etapas e Modalidade de Ensino Oferecidas',
                             'Outras Ofertas Educacionais',
                             'Latitude',
                             'Longitude']
                            
                                )
    #fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(mapbox_style="carto-positron")
    fig.update_traces(marker=dict(sizemin=2))
    return fig

fig = map_escolas()
#export_fig_html(fig, "locais_votacao_2022.html")
#fig.show()
fig.write_html("maps_escola.html")
